# %% [markdown]
# <h1>Data Processing</h1>
# <h3>By Abby Roberts</h3>

# %% [markdown]
# <h2>Import Libraries</h2>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <h2>Import Data</h2>

# %%
filepath = '../../Data/original/heart-disease.csv'
df = pd.read_csv(filepath)

# %%
"""
Columns: 
age, 
sex, 
chest pain (cp), 
resting blood pressure (trestbps), 
cholesterol (chol), 
fasting blood sugar (fbs), 
resting electrocardiographic result (restecg), 
maximum heart rate (thalach), 
exercise-induced angina (exang), 
ST depression (old peak), 
slope of peak ST segment (slope), 
number of major vessels (ca), 
thallium stress result (thal),
diagnosis of heart disease (num)
"""
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#   ca thal  num
# 0  0    6    0
# 1  3    3    2
# 2  2    7    1
# 3  0    3    0
# 4  0    3    0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    object
#  12  thal      303 non-null    object
#  13  num       303 non-null    int64
# dtypes: float64(1), int64(11), object(2)
# memory usage: 33.3+ KB

# %% [markdown]
# <h2>Clean Data</h2>
# <h3>Add target</h3>

# %%
# add target variable - if disease is greater than 1, has disease
df['target'] = np.where(df['num']==0, 0, 1)

# %%
# check value counts - should have 165 CVD, 138 normal
df['target'].value_counts()
# Out:
# target
# 0    164
# 1    139
# Name: count, dtype: int64

# %% [markdown]
# <h3>Remove bad entries</h3>

# %%
df['ca'].value_counts()
# Out:
# ca
# 0    176
# 1     65
# 2     38
# 3     20
# ?      4
# Name: count, dtype: int64

# %%
# remove ? rows
df = df[df['ca']!='?'].copy()

# %%
df['thal'].value_counts()
# Out:
# thal
# 3    164
# 7    115
# 6     18
# ?      2
# Name: count, dtype: int64

# %%
# remove ? rows
df = df[df['thal']!='?'].copy()

# %% [markdown]
# <h3>Add dummies</h3>

# %%
# make sex into actual names for easier understanding
df['sex'] = np.where(df['sex']==1, 'male', 'female')

# add dummies
df_sex_dummies = pd.get_dummies(df['sex'], prefix='sex')
df = pd.concat([df, df_sex_dummies], axis=1)

df.head()
# Out:
#    age     sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0   63    male   1       145   233    1        2      150      0      2.3
# 1   67    male   4       160   286    0        2      108      1      1.5
# 2   67    male   4       120   229    0        2      129      1      2.6
# 3   37    male   3       130   250    0        0      187      0      3.5
# 4   41  female   2       130   204    0        2      172      0      1.4
#
#    slope ca thal  num  target  sex_female  sex_male
# 0      3  0    6    0       0       False      True
# 1      2  3    3    2       1       False      True
# 2      2  2    7    1       1       False      True
# 3      3  0    3    0       0       False      True
# 4      1  0    3    0       0        True     False

# %%
# make chest pain into actual diagnosis names for easier understanding
df['cp'] = np.select([df['cp']==1, df['cp']==2, df['cp']==3, df['cp']==4],
                     ['typical angina', 'atypical angina', 'non-anginal pain', 'asymptomatic'])

# add dummies
df_cp_dummies = pd.get_dummies(df['cp'], prefix='cp')
df = pd.concat([df, df_cp_dummies], axis=1)

df.head()
# Out:
#    age     sex                cp  trestbps  chol  fbs  restecg  thalach  \
# 0   63    male    typical angina       145   233    1        2      150
# 1   67    male      asymptomatic       160   286    0        2      108
# 2   67    male      asymptomatic       120   229    0        2      129
# 3   37    male  non-anginal pain       130   250    0        0      187
# 4   41  female   atypical angina       130   204    0        2      172
#
#    exang  oldpeak  ...  ca thal num  target  sex_female  sex_male  \
# 0      0      2.3  ...   0    6   0       0       False      True
# 1      1      1.5  ...   3    3   2       1       False      True
# 2      1      2.6  ...   2    7   1       1       False      True
# 3      0      3.5  ...   0    3   0       0       False      True
# 4      0      1.4  ...   0    3   0       0        True     False
#
#    cp_asymptomatic  cp_atypical angina  cp_non-anginal pain  cp_typical angina
# 0            False               False                False               True
# 1             True               False                False              False
# 2             True               False                False              False
# 3            False               False                 True              False
# 4            False                True                False              False
#
# [5 rows x 21 columns]

# %%
# add marker for bad blood pressure (>=130)
df['trestbps_concerning'] = np.where(df['chol']>=130, 1, 0)

df.head()
# Out:
#    age     sex                cp  trestbps  chol  fbs  restecg  thalach  \
# 0   63    male    typical angina       145   233    1        2      150
# 1   67    male      asymptomatic       160   286    0        2      108
# 2   67    male      asymptomatic       120   229    0        2      129
# 3   37    male  non-anginal pain       130   250    0        0      187
# 4   41  female   atypical angina       130   204    0        2      172
#
#    exang  oldpeak  ...  thal num target  sex_female  sex_male  \
# 0      0      2.3  ...     6   0      0       False      True
# 1      1      1.5  ...     3   2      1       False      True
# 2      1      2.6  ...     7   1      1       False      True
# 3      0      3.5  ...     3   0      0       False      True
# 4      0      1.4  ...     3   0      0        True     False
#
#    cp_asymptomatic  cp_atypical angina  cp_non-anginal pain  \
# 0            False               False                False
# 1             True               False                False
# 2             True               False                False
# 3            False               False                 True
# 4            False                True                False
#
#    cp_typical angina  trestbps_concerning
# 0               True                    1
# 1              False                    1
# 2              False                    1
# 3              False                    1
# 4              False                    1
#
# [5 rows x 22 columns]

# %%
# add marker for bad cholesterol (>=200)
df['chol_concerning'] = np.where(df['chol']>=200, 1, 0)

df.head()
# Out:
#    age     sex                cp  trestbps  chol  fbs  restecg  thalach  \
# 0   63    male    typical angina       145   233    1        2      150
# 1   67    male      asymptomatic       160   286    0        2      108
# 2   67    male      asymptomatic       120   229    0        2      129
# 3   37    male  non-anginal pain       130   250    0        0      187
# 4   41  female   atypical angina       130   204    0        2      172
#
#    exang  oldpeak  ...  num target sex_female  sex_male  cp_asymptomatic  \
# 0      0      2.3  ...    0      0      False      True            False
# 1      1      1.5  ...    2      1      False      True             True
# 2      1      2.6  ...    1      1      False      True             True
# 3      0      3.5  ...    0      0      False      True            False
# 4      0      1.4  ...    0      0       True     False            False
#
#    cp_atypical angina  cp_non-anginal pain  cp_typical angina  \
# 0               False                False               True
# 1               False                False              False
# 2               False                False              False
# 3               False                 True              False
# 4                True                False              False
#
#    trestbps_concerning  chol_concerning
# 0                    1                1
# 1                    1                1
# 2                    1                1
# 3                    1                1
# 4                    1                1
#
# [5 rows x 23 columns]

# %%
# make resting ecg into actual diagnosis names for easier understanding
df['restecg'] = np.select([df['restecg']==0, df['restecg']==1, df['restecg']==2],
                          ['no issues', 'non-normal heart beat', 'enlarged left ventricular'])

# add dummies
df_restecg_dummies = pd.get_dummies(df['restecg'], prefix='restecg')
df = pd.concat([df, df_restecg_dummies], axis=1)

df.head()
# Out:
#    age     sex                cp  trestbps  chol  fbs  \
# 0   63    male    typical angina       145   233    1
# 1   67    male      asymptomatic       160   286    0
# 2   67    male      asymptomatic       120   229    0
# 3   37    male  non-anginal pain       130   250    0
# 4   41  female   atypical angina       130   204    0
#
#                      restecg  thalach  exang  oldpeak  ...  sex_male  \
# 0  enlarged left ventricular      150      0      2.3  ...      True
# 1  enlarged left ventricular      108      1      1.5  ...      True
# 2  enlarged left ventricular      129      1      2.6  ...      True
# 3                  no issues      187      0      3.5  ...      True
# 4  enlarged left ventricular      172      0      1.4  ...     False
#
#   cp_asymptomatic cp_atypical angina  cp_non-anginal pain  cp_typical angina  \
# 0           False              False                False               True
# 1            True              False                False              False
# 2            True              False                False              False
# 3           False              False                 True              False
# 4           False               True                False              False
#
#    trestbps_concerning  chol_concerning  restecg_enlarged left ventricular  \
# 0                    1                1                               True
# 1                    1                1                               True
# 2                    1                1                               True
# 3                    1                1                              False
# 4                    1                1                               True
#
#    restecg_no issues  restecg_non-normal heart beat
# 0              False                          False
# 1              False                          False
# 2              False                          False
# 3               True                          False
# 4              False                          False
#
# [5 rows x 26 columns]

# %%
# add marker for bad maximum heart rate (>=140)
df['thalach_concerning'] = np.where(df['thalach']>=140, 1, 0)

df.head()
# Out:
#    age     sex                cp  trestbps  chol  fbs  \
# 0   63    male    typical angina       145   233    1
# 1   67    male      asymptomatic       160   286    0
# 2   67    male      asymptomatic       120   229    0
# 3   37    male  non-anginal pain       130   250    0
# 4   41  female   atypical angina       130   204    0
#
#                      restecg  thalach  exang  oldpeak  ...  cp_asymptomatic  \
# 0  enlarged left ventricular      150      0      2.3  ...            False
# 1  enlarged left ventricular      108      1      1.5  ...             True
# 2  enlarged left ventricular      129      1      2.6  ...             True
# 3                  no issues      187      0      3.5  ...            False
# 4  enlarged left ventricular      172      0      1.4  ...            False
#
#   cp_atypical angina cp_non-anginal pain  cp_typical angina  \
# 0              False               False               True
# 1              False               False              False
# 2              False               False              False
# 3              False                True              False
# 4               True               False              False
#
#    trestbps_concerning  chol_concerning  restecg_enlarged left ventricular  \
# 0                    1                1                               True
# 1                    1                1                               True
# 2                    1                1                               True
# 3                    1                1                              False
# 4                    1                1                               True
#
#    restecg_no issues  restecg_non-normal heart beat  thalach_concerning
# 0              False                          False                   1
# 1              False                          False                   0
# 2              False                          False                   0
# 3               True                          False                   1
# 4              False                          False                   1
#
# [5 rows x 27 columns]

# %%
# make slope into actual diagnosis names for easier understanding
df['slope'] = np.select([df['slope']==1, df['slope']==2],
                        ['typical', 'unhealthy'], default='upsloping')

# add dummies
df_slope_dummies = pd.get_dummies(df['slope'], prefix='slope')
df = pd.concat([df, df_slope_dummies], axis=1)

df.head()
# Out:
#    age     sex                cp  trestbps  chol  fbs  \
# 0   63    male    typical angina       145   233    1
# 1   67    male      asymptomatic       160   286    0
# 2   67    male      asymptomatic       120   229    0
# 3   37    male  non-anginal pain       130   250    0
# 4   41  female   atypical angina       130   204    0
#
#                      restecg  thalach  exang  oldpeak  ... cp_typical angina  \
# 0  enlarged left ventricular      150      0      2.3  ...              True
# 1  enlarged left ventricular      108      1      1.5  ...             False
# 2  enlarged left ventricular      129      1      2.6  ...             False
# 3                  no issues      187      0      3.5  ...             False
# 4  enlarged left ventricular      172      0      1.4  ...             False
#
#   trestbps_concerning chol_concerning  restecg_enlarged left ventricular  \
# 0                   1               1                               True
# 1                   1               1                               True
# 2                   1               1                               True
# 3                   1               1                              False
# 4                   1               1                               True
#
#    restecg_no issues  restecg_non-normal heart beat  thalach_concerning  \
# 0              False                          False                   1
# 1              False                          False                   0
# 2              False                          False                   0
# 3               True                          False                   1
# 4              False                          False                   1
#
#    slope_typical  slope_unhealthy  slope_upsloping
# 0          False            False             True
# 1          False             True            False
# 2          False             True            False
# 3          False            False             True
# 4           True            False            False
#
# [5 rows x 30 columns]

# %%
# add marker for number of major vessels colored by flouroscopy (==0)
df['ca_concerning'] = np.where(df['ca']=='0', 1, 0)

df.head()
# Out:
#    age     sex                cp  trestbps  chol  fbs  \
# 0   63    male    typical angina       145   233    1
# 1   67    male      asymptomatic       160   286    0
# 2   67    male      asymptomatic       120   229    0
# 3   37    male  non-anginal pain       130   250    0
# 4   41  female   atypical angina       130   204    0
#
#                      restecg  thalach  exang  oldpeak  ...  \
# 0  enlarged left ventricular      150      0      2.3  ...
# 1  enlarged left ventricular      108      1      1.5  ...
# 2  enlarged left ventricular      129      1      2.6  ...
# 3                  no issues      187      0      3.5  ...
# 4  enlarged left ventricular      172      0      1.4  ...
#
#   trestbps_concerning chol_concerning restecg_enlarged left ventricular  \
# 0                   1               1                              True
# 1                   1               1                              True
# 2                   1               1                              True
# 3                   1               1                             False
# 4                   1               1                              True
#
#    restecg_no issues  restecg_non-normal heart beat  thalach_concerning  \
# 0              False                          False                   1
# 1              False                          False                   0
# 2              False                          False                   0
# 3               True                          False                   1
# 4              False                          False                   1
#
#    slope_typical  slope_unhealthy  slope_upsloping  ca_concerning
# 0          False            False             True              1
# 1          False             True            False              0
# 2          False             True            False              0
# 3          False            False             True              1
# 4           True            False            False              1
#
# [5 rows x 31 columns]

# %%
# make thalium stress level into actual diagnosis names for easier understanding
df['thal'] = np.select([df['thal']=='3', df['thal']=='6', df['thal']=='7'],
                        ['normal', 'fixed defect', 'reversable defect'])

# add dummies
df_thal_dummies = pd.get_dummies(df['thal'], prefix='thal')
df = pd.concat([df, df_thal_dummies], axis=1)

df.head()
# Out:
#    age     sex                cp  trestbps  chol  fbs  \
# 0   63    male    typical angina       145   233    1
# 1   67    male      asymptomatic       160   286    0
# 2   67    male      asymptomatic       120   229    0
# 3   37    male  non-anginal pain       130   250    0
# 4   41  female   atypical angina       130   204    0
#
#                      restecg  thalach  exang  oldpeak  ... restecg_no issues  \
# 0  enlarged left ventricular      150      0      2.3  ...             False
# 1  enlarged left ventricular      108      1      1.5  ...             False
# 2  enlarged left ventricular      129      1      2.6  ...             False
# 3                  no issues      187      0      3.5  ...              True
# 4  enlarged left ventricular      172      0      1.4  ...             False
#
#   restecg_non-normal heart beat thalach_concerning  slope_typical  \
# 0                         False                  1          False
# 1                         False                  0          False
# 2                         False                  0          False
# 3                         False                  1          False
# 4                         False                  1           True
#
#    slope_unhealthy  slope_upsloping  ca_concerning  thal_fixed defect  \
# 0            False             True              1               True
# 1             True            False              0              False
# 2             True            False              0              False
# 3            False             True              1              False
# 4            False            False              1              False
#
#    thal_normal  thal_reversable defect
# 0        False                   False
# 1         True                   False
# 2        False                    True
# 3         True                   False
# 4         True                   False
#
# [5 rows x 34 columns]

# %% [markdown]
# <h3>Update Data Types</h3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 0 to 301
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   age                                297 non-null    int64
#  1   sex                                297 non-null    object
#  2   cp                                 297 non-null    object
#  3   trestbps                           297 non-null    int64
#  4   chol                               297 non-null    int64
#  5   fbs                                297 non-null    int64
#  6   restecg                            297 non-null    object
#  7   thalach                            297 non-null    int64
#  8   exang                              297 non-null    int64
#  9   oldpeak                            297 non-null    float64
#  10  slope                              297 non-null    object
#  11  ca                                 297 non-null    object
#  12  thal                               297 non-null    object
#  13  num                                297 non-null    int64
#  14  target                             297 non-null    int32
#  15  sex_female                         297 non-null    bool
#  16  sex_male                           297 non-null    bool
#  17  cp_asymptomatic                    297 non-null    bool
#  18  cp_atypical angina                 297 non-null    bool
#  19  cp_non-anginal pain                297 non-null    bool
#  20  cp_typical angina                  297 non-null    bool
#  21  trestbps_concerning                297 non-null    int32
#  22  chol_concerning                    297 non-null    int32
#  23  restecg_enlarged left ventricular  297 non-null    bool
#  24  restecg_no issues                  297 non-null    bool
#  25  restecg_non-normal heart beat      297 non-null    bool
#  26  thalach_concerning                 297 non-null    int32
#  27  slope_typical                      297 non-null    bool
#  28  slope_unhealthy                    297 non-null    bool
#  29  slope_upsloping                    297 non-null    bool
#  30  ca_concerning                      297 non-null    int32
#  31  thal_fixed defect                  297 non-null    bool
#  32  thal_normal                        297 non-null    bool
#  33  thal_reversable defect             297 non-null    bool
# dtypes: bool(15), float64(1), int32(5), int64(7), object(6)
# memory usage: 45.0+ KB

# %%
# change ca to int
df['ca'] = df['ca'].astype(int)

# %%
# drop text columns
df.drop(columns=['sex', 'cp', 'restecg', 'slope', 'thal'], inplace=True)

# %%
# drop heart disease rating - only using target
df.drop(columns=['num'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 297 entries, 0 to 301
# Data columns (total 28 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   age                                297 non-null    int64
#  1   trestbps                           297 non-null    int64
#  2   chol                               297 non-null    int64
#  3   fbs                                297 non-null    int64
#  4   thalach                            297 non-null    int64
#  5   exang                              297 non-null    int64
#  6   oldpeak                            297 non-null    float64
#  7   ca                                 297 non-null    int32
#  8   target                             297 non-null    int32
#  9   sex_female                         297 non-null    bool
#  10  sex_male                           297 non-null    bool
#  11  cp_asymptomatic                    297 non-null    bool
#  12  cp_atypical angina                 297 non-null    bool
#  13  cp_non-anginal pain                297 non-null    bool
#  14  cp_typical angina                  297 non-null    bool
#  15  trestbps_concerning                297 non-null    int32
#  16  chol_concerning                    297 non-null    int32
#  17  restecg_enlarged left ventricular  297 non-null    bool
#  18  restecg_no issues                  297 non-null    bool
#  19  restecg_non-normal heart beat      297 non-null    bool
#  20  thalach_concerning                 297 non-null    int32
#  21  slope_typical                      297 non-null    bool
#  22  slope_unhealthy                    297 non-null    bool
#  23  slope_upsloping                    297 non-null    bool
#  24  ca_concerning                      297 non-null    int32
#  25  thal_fixed defect                  297 non-null    bool
#  26  thal_normal                        297 non-null    bool
#  27  thal_reversable defect             297 non-null    bool
# dtypes: bool(15), float64(1), int32(6), int64(6)
# memory usage: 29.9 KB

# %%
df.head()
# Out:
#    age  trestbps  chol  fbs  thalach  exang  oldpeak  ca  target  sex_female  \
# 0   63       145   233    1      150      0      2.3   0       0       False
# 1   67       160   286    0      108      1      1.5   3       1       False
# 2   67       120   229    0      129      1      2.6   2       1       False
# 3   37       130   250    0      187      0      3.5   0       0       False
# 4   41       130   204    0      172      0      1.4   0       0        True
#
#    ...  restecg_no issues  restecg_non-normal heart beat  thalach_concerning  \
# 0  ...              False                          False                   1
# 1  ...              False                          False                   0
# 2  ...              False                          False                   0
# 3  ...               True                          False                   1
# 4  ...              False                          False                   1
#
#    slope_typical  slope_unhealthy  slope_upsloping  ca_concerning  \
# 0          False            False             True              1
# 1          False             True            False              0
# 2          False             True            False              0
# 3          False            False             True              1
# 4           True            False            False              1
#
#    thal_fixed defect  thal_normal  thal_reversable defect
# 0               True        False                   False
# 1              False         True                   False
# 2              False        False                    True
# 3              False         True                   False
# 4              False         True                   False
#
# [5 rows x 28 columns]

# %% [markdown]
# <h2>Save the dataframe</h2>

# %%
# save dataframe to csv
df.to_csv('../../Data/processed/df_preprocessed.csv', index=False)
